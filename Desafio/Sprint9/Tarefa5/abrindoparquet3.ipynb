# %% [markdown]
# Estou apenas conferindo se o parquet deu certo localmente.
#
# Deu um total de 753 linhas e 12 colunas.
#
# id
# tituloprincipal
# titulooriginal
# tempominutos
# anolancamento
# genero
# notamedia
# numerovotos
# imdb_id
# production_countries
# vote_average
# vote_count

# %%
pd.read_parquet(parquet_file, engine='auto')
# Out:
#             id                     tituloprincipal        titulooriginal  \
# 0    tt0418689                Flags of Our Fathers  Flags of Our Fathers
# 1    tt9777666                    The Tomorrow War      The Tomorrow War
# 2    tt0076759  Star Wars: Episode IV - A New Hope             Star Wars
# 3    tt2719848                             Everest               Everest
# 4    tt0429493                          The A-Team            The A-Team
# ..         ...                                 ...                   ...
# 748  tt2704998                          Game Night            Game Night
# 749  tt0297181                               I Spy                 I Spy
# 750  tt0480255                          The Losers            The Losers
# 751  tt0115759                        Broken Arrow          Broken Arrow
# 752  tt1228705                          Iron Man 2            Iron Man 2
#
#      tempominutos  anolancamento                      genero notamedia  \
# ...

# %%
# !python -m pip install pyarrow

# %%
import pandas as pd

# %%
parquet_file = r'C:\Users\jadem\PycharmProjects\curso_python2\desafio2'
